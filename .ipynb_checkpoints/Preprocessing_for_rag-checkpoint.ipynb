# %%
import pandas as pd
import numpy as np
from IPython.display import display
import os

# %%
folder_path = 'DATA EXPLORER CONTEST/News/'

# %%
data = {}
for filename in sorted(os.listdir(folder_path)):
  if os.path.isfile(os.path.join(folder_path, filename)):
    print(f"Accessing file: {filename}")
    if filename[-4:]=='xlsx':
        data[filename] = pd.read_excel(os.path.join(folder_path, filename))
    else:
        data[filename] = pd.read_csv(os.path.join(folder_path, filename))
    display(data[filename].head())
# Out:
# Accessing file: CafeF_News_FPT_CMG.xlsx
#                                                title       date  \
# 0  Phiên 12/3: Khối ngoại bán ròng đột biến hơn 9... 2025-03-12
# 1  Chứng khoán ngày mai (12-3): VN-Index tiếp tục... 2025-03-11
# 2  FPT "bắt tay" tỉnh Bắc Giang phát triển toàn d... 2025-03-11
# 3  Tự doanh CTCK bất ngờ trở lại "gom" một mã ngâ... 2025-03-11
# 4                   Chứng khoán thoát hiểm 'phút 89' 2025-03-11
#
#                                              summary
# 0  Vietnam Stock Market Summary (March 12, 2025)_...
# 1  Market Summary - Vietnam Securities Market (Ma...
# 2  Market News Summary - March 11, 2025_x000D_\nP...
# 3  Market Summary (March 11, 2025)_x000D_\nVN-Ind...
# 4  Market Summary (March 11, 2025)_x000D_\nMarket...
# Accessing file: news_dividend_issue (FPT_CMG)_processed.csv
#    No StockID Exchange Ex-Dividend Date Record Date Execution Date  \
# 0   1     FPT     HOSE       02/12/2024  03/12/2024     13/12/2024
# 1   2     FPT     HOSE       12/06/2024  13/06/2024     20/06/2024
# 2   3     FPT     HOSE       12/06/2024  13/06/2024            NaN
# 3   4     FPT     HOSE       24/08/2023  25/08/2023     12/09/2023
# 4   5     FPT     HOSE       05/07/2023  06/07/2023     13/07/2023
#
#                                     Event Content                Event Type
# 0  Trả cổ tức đợt 1/2024 bằng tiền, 1,000 đồng/CP  Trả cổ tức bằng tiền mặt
# 1  Trả cổ tức đợt 2/2023 bằng tiền, 1,000 đồng/CP  Trả cổ tức bằng tiền mặt
# 2                     Thưởng cổ phiếu, tỷ lệ 20:3           Thưởng cổ phiếu
# 3  Trả cổ tức đợt 1/2023 bằng tiền, 1,000 đồng/CP  Trả cổ tức bằng tiền mặt
# 4  Trả cổ tức đợt 2/2022 bằng tiền, 1,000 đồng/CP  Trả cổ tức bằng tiền mặt
# Accessing file: news_internal_transactions (FPT_CMG)_processed.csv
#    No StockID        Transaction Type      Executor Name    Executor Position  \
# 0   1     FPT            GD CĐ nội bộ     Bùi Quang Ngọc           Phó CTHĐQT
# 1   2     FPT            GD CĐ nội bộ  Nguyễn Việt Thắng                 TBKS
# 2   3     FPT  GD của người liên quan    Đỗ Thị Ngọc Mai                  NaN
# 3   4     FPT            GD CĐ nội bộ    Mai Thị Lan Anh  Người ủy quyền CBTT
# 4   5     FPT            GD CĐ nội bộ   Nguyễn Khải Hoàn               TV BKS
#
#   Related Person Name Related Person Position Relation  \
# 0                 NaN                     NaN      NaN
# 1                 NaN                     NaN      NaN
# 2          Đỗ Cao Bảo                 TV HĐQT      Con
# 3                 NaN                     NaN      NaN
# 4                 NaN                     NaN      NaN
#
#   Before Transaction Volume  Before Transaction Percentage  \
# 0                23,961,492                           1.63
# 1                   185,841                            NaN
# 2                 1,046,636                            NaN
# 3                        36                            NaN
# 4                 1,234,527                            NaN
#
#   Registered Transaction Volume Registered From Date Registered To Date  \
# 0                    -2,000,000           06/02/2025         28/02/2025
# 1                       -60,000           17/10/2024         15/11/2024
# 2                        75,659           08/10/2024         09/10/2024
# 3                         3,025           08/10/2024         09/10/2024
# 4                       182,203           08/10/2024         09/10/2024
#
#   Executed Transaction Volume Executed From Date Executed To Date  \
# 0                  -2,000,000         11/02/2025       11/02/2025
# 1                     -60,000         17/10/2024       13/11/2024
# 2                         NaN                NaN              NaN
# 3                         NaN                NaN              NaN
# 4                         NaN                NaN              NaN
#
#   After Transaction Volume  After Transaction Percentage
# 0               21,961,492                          1.49
# 1                  125,841                           NaN
# 2                      NaN                           NaN
# 3                      NaN                           NaN
# 4                      NaN                           NaN
# Accessing file: news_shareholder_meeting (FPT_CMG)_processed.csv
#    No StockID Exchange Ex-Rights Date Record Date Execution Date  \
# 0   1     FPT     HOSE     06/03/2025  07/03/2025     15/04/2025
# 1   2     FPT     HOSE     04/03/2024  05/03/2024     10/04/2024
# 2   1     CMG     HOSE     17/06/2024  18/06/2024     25/07/2024
# 3   2     CMG     HOSE     14/06/2023  15/06/2023     26/07/2023
#
#                        Event Type
# 0  Họp ĐHĐCĐ thường niên năm 2025
# 1  Họp ĐHĐCĐ thường niên năm 2024
# 2  Họp ĐHĐCĐ thường niên năm 2024
# 3  Họp ĐHĐCĐ thường niên năm 2023

# %%
def clean_data(data_dict):
    news = data_dict.copy()
    for key, value in news.items():
        print(f"Làm sạch file dữ liệu: {key}")
        df = value.copy()
        if key=='CafeF_News_FPT_CMG.xlsx':
            df['summary'] = df['summary'].str.replace(r'_x000D_\n', '\n', regex=True)
            df['summary'] = df['summary'].str.replace(r'_x000D_', '\n', regex=True)
            df['summary'] = df['summary'].str.strip()
            df['date'] = pd.to_datetime(df['date'])
        elif key=='news_dividend_issue (FPT_CMG)_processed.csv':
            # Chuyển đổi định dạng các cột ngày
            date_cols = ['Ex-Dividend Date', 'Record Date', 'Execution Date']
            for col in date_cols:
                df[col] = pd.to_datetime(df[col], dayfirst=True, errors='coerce')
            # Trích giá trị cổ tức
            df['Dividend (VND)'] = df['Event Content'].str.extract(r'(\d{1,3}(?:,\d{3})*) đồng/CP')[0]
            df['Dividend (VND)'] = df['Dividend (VND)'].str.replace(',', '', regex=False).astype(float)
            # Trích xuất tỷ lệ thưởng cổ phiếu, ví dụ "20:3" -> 6.67
            ratio_df = df['Event Content'].str.extract(r'(\d+):(\d+)')
            df['Bonus Ratio'] = (
                ratio_df.dropna()
                .apply(lambda x: int(x[0])/int(x[1]), axis=1)
                if not ratio_df.isnull().all(axis=None)
                else None
            )
            df['Event Type'] = df['Event Type'].str.lower().str.strip()
        elif key=='news_internal_transactions (FPT_CMG)_processed.csv':
            # Chuyển các cột ngày sang kiểu datetime
            date_cols = [
                'Registered From Date', 'Registered To Date',
                'Executed From Date', 'Executed To Date'
            ]
            for col in date_cols:
                df[col] = pd.to_datetime(df[col], dayfirst=True, errors='coerce')
            # Các cột số có thể chứa dấu phẩy => loại bỏ dấu phẩy và chuyển thành float
            number_cols = [
                'Before Transaction Volume', 'Before Transaction Percentage',
                'Registered Transaction Volume', 'Executed Transaction Volume',
                'After Transaction Volume', 'After Transaction Percentage'
            ]
            for col in number_cols:
                df[col] = (
                    df[col].astype(str)
                    .str.replace(',', '', regex=False)
                    .str.replace('−', '-', regex=False)  # xử lý dấu âm đặc biệt nếu có
                    .replace(['nan', 'NA', 'None'], np.nan)
                ).astype(float)
            # Chuẩn hóa định dạng text: xóa khoảng trắng đầu/cuối
            text_cols = ['StockID', 'Transaction Type', 'Executor Name',
                         'Executor Position', 'Related Person Name',
                         'Related Person Position', 'Relation']
            
            for col in text_cols:
                df[col] = df[col].astype(str).str.strip()
                df[col] = df[col].replace('nan', 'Không rõ')
        elif key=='news_shareholder_meeting (FPT_CMG)_processed.csv':
            # Danh sách các cột ngày cần chuyển đổi kiểu dữ liệu
            date_cols = ['Ex-Rights Date', 'Record Date', 'Execution Date']
            for col in date_cols:
                df[col] = pd.to_datetime(df[col], dayfirst=True, errors='coerce')
            # Chuẩn hóa các cột kiểu text: xóa khoảng trắng đầu/cuối
            text_cols = ['StockID', 'Exchange', 'Event Type']
            for col in text_cols:
                df[col] = df[col].astype(str).str.strip()
        else:
            pass
        news[key] = df
    return news

# %%
clean_data = clean_data(data)
for key, value in clean_data.items():
    print(key)
    display(value.head())
# Out:
# Làm sạch file dữ liệu: CafeF_News_FPT_CMG.xlsx
# Làm sạch file dữ liệu: news_dividend_issue (FPT_CMG)_processed.csv
# Làm sạch file dữ liệu: news_internal_transactions (FPT_CMG)_processed.csv
# Làm sạch file dữ liệu: news_shareholder_meeting (FPT_CMG)_processed.csv
# CafeF_News_FPT_CMG.xlsx
#                                                title       date  \
# 0  Phiên 12/3: Khối ngoại bán ròng đột biến hơn 9... 2025-03-12
# 1  Chứng khoán ngày mai (12-3): VN-Index tiếp tục... 2025-03-11
# 2  FPT "bắt tay" tỉnh Bắc Giang phát triển toàn d... 2025-03-11
# 3  Tự doanh CTCK bất ngờ trở lại "gom" một mã ngâ... 2025-03-11
# 4                   Chứng khoán thoát hiểm 'phút 89' 2025-03-11
#
#                                              summary
# 0  Vietnam Stock Market Summary (March 12, 2025)\...
# 1  Market Summary - Vietnam Securities Market (Ma...
# 2  Market News Summary - March 11, 2025\nPartners...
# 3  Market Summary (March 11, 2025)\nVN-Index Move...
# 4  Market Summary (March 11, 2025)\nMarket Moveme...
# news_dividend_issue (FPT_CMG)_processed.csv
#    No StockID Exchange Ex-Dividend Date Record Date Execution Date  \
# 0   1     FPT     HOSE       2024-12-02  2024-12-03     2024-12-13
# 1   2     FPT     HOSE       2024-06-12  2024-06-13     2024-06-20
# 2   3     FPT     HOSE       2024-06-12  2024-06-13            NaT
# 3   4     FPT     HOSE       2023-08-24  2023-08-25     2023-09-12
# 4   5     FPT     HOSE       2023-07-05  2023-07-06     2023-07-13
#
#                                     Event Content                Event Type  \
# 0  Trả cổ tức đợt 1/2024 bằng tiền, 1,000 đồng/CP  trả cổ tức bằng tiền mặt
# 1  Trả cổ tức đợt 2/2023 bằng tiền, 1,000 đồng/CP  trả cổ tức bằng tiền mặt
# 2                     Thưởng cổ phiếu, tỷ lệ 20:3           thưởng cổ phiếu
# 3  Trả cổ tức đợt 1/2023 bằng tiền, 1,000 đồng/CP  trả cổ tức bằng tiền mặt
# 4  Trả cổ tức đợt 2/2022 bằng tiền, 1,000 đồng/CP  trả cổ tức bằng tiền mặt
#
#    Dividend (VND)  Bonus Ratio
# 0          1000.0          NaN
# 1          1000.0          NaN
# 2             NaN     6.666667
# 3          1000.0          NaN
# 4          1000.0          NaN
# news_internal_transactions (FPT_CMG)_processed.csv
#    No StockID        Transaction Type      Executor Name    Executor Position  \
# 0   1     FPT            GD CĐ nội bộ     Bùi Quang Ngọc           Phó CTHĐQT
# 1   2     FPT            GD CĐ nội bộ  Nguyễn Việt Thắng                 TBKS
# 2   3     FPT  GD của người liên quan    Đỗ Thị Ngọc Mai             Không rõ
# 3   4     FPT            GD CĐ nội bộ    Mai Thị Lan Anh  Người ủy quyền CBTT
# 4   5     FPT            GD CĐ nội bộ   Nguyễn Khải Hoàn               TV BKS
#
#   Related Person Name Related Person Position  Relation  \
# 0            Không rõ                Không rõ  Không rõ
# 1            Không rõ                Không rõ  Không rõ
# 2          Đỗ Cao Bảo                 TV HĐQT       Con
# 3            Không rõ                Không rõ  Không rõ
# 4            Không rõ                Không rõ  Không rõ
#
#    Before Transaction Volume  Before Transaction Percentage  \
# 0                 23961492.0                           1.63
# 1                   185841.0                            NaN
# 2                  1046636.0                            NaN
# 3                       36.0                            NaN
# 4                  1234527.0                            NaN
#
#    Registered Transaction Volume Registered From Date Registered To Date  \
# 0                     -2000000.0           2025-02-06         2025-02-28
# 1                       -60000.0           2024-10-17         2024-11-15
# 2                        75659.0           2024-10-08         2024-10-09
# 3                         3025.0           2024-10-08         2024-10-09
# 4                       182203.0           2024-10-08         2024-10-09
#
#    Executed Transaction Volume Executed From Date Executed To Date  \
# 0                   -2000000.0         2025-02-11       2025-02-11
# 1                     -60000.0         2024-10-17       2024-11-13
# 2                          NaN                NaT              NaT
# 3                          NaN                NaT              NaT
# 4                          NaN                NaT              NaT
#
#    After Transaction Volume  After Transaction Percentage
# 0                21961492.0                          1.49
# 1                  125841.0                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
# news_shareholder_meeting (FPT_CMG)_processed.csv
#    No StockID Exchange Ex-Rights Date Record Date Execution Date  \
# 0   1     FPT     HOSE     2025-03-06  2025-03-07     2025-04-15
# 1   2     FPT     HOSE     2024-03-04  2024-03-05     2024-04-10
# 2   1     CMG     HOSE     2024-06-17  2024-06-18     2024-07-25
# 3   2     CMG     HOSE     2023-06-14  2023-06-15     2023-07-26
#
#                        Event Type
# 0  Họp ĐHĐCĐ thường niên năm 2025
# 1  Họp ĐHĐCĐ thường niên năm 2024
# 2  Họp ĐHĐCĐ thường niên năm 2024
# 3  Họp ĐHĐCĐ thường niên năm 2023

# %%
for key, value in clean_data.items():
    print("Tên file:")
    print(key)
    print("Tên các cột dữ liệu:")
    print(value.info())
# Out:
# Tên file:
# CafeF_News_FPT_CMG.xlsx
# Tên các cột dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909 entries, 0 to 908
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    909 non-null    object
#  1   date     909 non-null    datetime64[ns]
#  2   summary  909 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 21.4+ KB
# None
# Tên file:
# news_dividend_issue (FPT_CMG)_processed.csv
# Tên các cột dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No                10 non-null     int64
#  1   StockID           10 non-null     object
#  2   Exchange          10 non-null     object
#  3   Ex-Dividend Date  10 non-null     datetime64[ns]
#  4   Record Date       10 non-null     datetime64[ns]
#  5   Execution Date    5 non-null      datetime64[ns]
#  6   Event Content     10 non-null     object
#  7   Event Type        10 non-null     object
#  8   Dividend (VND)    5 non-null      float64
#  9   Bonus Ratio       5 non-null      float64
# dtypes: datetime64[ns](3), float64(2), int64(1), object(4)
# memory usage: 932.0+ bytes
# None
# Tên file:
# news_internal_transactions (FPT_CMG)_processed.csv
# Tên các cột dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   No                             64 non-null     int64
#  1   StockID                        64 non-null     object
#  2   Transaction Type               64 non-null     object
#  3   Executor Name                  64 non-null     object
#  4   Executor Position              64 non-null     object
#  5   Related Person Name            64 non-null     object
#  6   Related Person Position        64 non-null     object
#  7   Relation                       64 non-null     object
#  8   Before Transaction Volume      49 non-null     float64
#  9   Before Transaction Percentage  13 non-null     float64
#  10  Registered Transaction Volume  51 non-null     float64
#  11  Registered From Date           51 non-null     datetime64[ns]
#  12  Registered To Date             51 non-null     datetime64[ns]
#  13  Executed Transaction Volume    51 non-null     float64
#  14  Executed From Date             55 non-null     datetime64[ns]
#  15  Executed To Date               55 non-null     datetime64[ns]
#  16  After Transaction Volume       54 non-null     float64
#  17  After Transaction Percentage   25 non-null     float64
# dtypes: datetime64[ns](4), float64(6), int64(1), object(7)
# memory usage: 9.1+ KB
# None
# Tên file:
# news_shareholder_meeting (FPT_CMG)_processed.csv
# Tên các cột dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              4 non-null      int64
#  1   StockID         4 non-null      object
#  2   Exchange        4 non-null      object
#  3   Ex-Rights Date  4 non-null      datetime64[ns]
#  4   Record Date     4 non-null      datetime64[ns]
#  5   Execution Date  4 non-null      datetime64[ns]
#  6   Event Type      4 non-null      object
# dtypes: datetime64[ns](3), int64(1), object(3)
# memory usage: 356.0+ bytes
# None
